# %% [markdown]
# # Introducción

# %% [markdown]
# # Antecedentes

# %% [markdown]
# # Objetivos

# %% [markdown]
# # Planteamiento del Problema

# %% [markdown]
# # EDA

# %% [markdown]
# # Data Wrangling (Limpieza de Datos)

# %% [markdown]
# # Conclusiones

# %% [markdown]
# # Referencias
